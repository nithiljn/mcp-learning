# %%
from pageindex import PageIndexClient
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

# %%
pi_client = PageIndexClient(api_key = os.getenv("PAGE_INDEX_API_KEY"))

# %%
path = "../DATA/MCP.pdf"
print(f"Upload doc {path}")
res=pi_client.submit_document(path)
doc_id=res["doc_id"]
doc_id
# Out:
# Upload doc ../DATA/MCP.pdf
# 'pi-cmqgvw65902rr01pk9mclab1h'

# %%
import time
while True:
    status_result = pi_client.get_document(doc_id)
    status = status_result.get("status")
    print(f" Status :{status}")

    if status =="completed":
        print("Tree index read ")
        break
    elif status == "failed":
        print(f" status failed ")

    time.sleep(5)
# Out:
#  Status :completed
# Tree index read
